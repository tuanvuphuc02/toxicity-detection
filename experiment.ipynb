# %%
import pandas as pd

# %%
path = "../input/jigsaw-unintended-bias-in-toxicity-classification/train.csv"

df = pd.read_csv(path)

# %%
df = df[df["target"] > 0.8]

# %%
df
# Out:
#               id    target                                       comment_text  \
# 4          59856  0.893617               haha you guys are a bunch of losers.
# 31        239607  0.912500  Yet call out all Muslims for the acts of a few...
# 34        239612  0.830769  This bitch is nuts. Who would read a book by a...
# 289       240311  0.968750                                   You're an idiot.
# 306       240329  0.900000  Who cares!? Stark trek and Star Wars fans are ...
# ...          ...       ...                                                ...
# 1804524  6333372  0.866667  Butts was stupid enough to lay out the charade...
# 1804600  6333475  0.805556  Wow. What entitled, arrogant , immature, loser...
# 1804712  6333661  0.862745                                        Human scum.
# 1804753  6333721  0.833333  I saved where I could because my children matt...
# 1804825  6333841  0.833333  Who is the jerk in the last row between the C ...
#
# ...

# %%
df["comment_text"][:10].values
# Out:
# array(['haha you guys are a bunch of losers.',
#        "Yet call out all Muslims for the acts of a few will get you pilloried.   So why is it okay to smear an entire religion over these few idiots?  Or is this because it's okay to bash Christian sects?",
#        'This bitch is nuts. Who would read a book by a woman.',
#        "You're an idiot.",
#        'Who cares!? Stark trek and Star Wars fans are all dorks who never get laid.',
#        "Nincompoop, that's a nice one! I'm partial to silly goose.",
#        'Sorry to have to do this, but just to see if profanity filtering is enabled: fuck.',
#        "testing purposes: \n\nyou are an idiot and i can't stand ignorant donutholes.",
#        "For the purposes of testing, here's my contribution:\n\nlol wut wat a bunch of bullshit\n\nthe author is a delusional stupid jerk full of crap\n\n(I just can't bring myself to use stronger profanity and personal attacks.)",
# ...
